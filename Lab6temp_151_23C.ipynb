# %% [markdown]
# ## MATH 151 Lab  6

# %% [markdown]
# Put team members' names and section number here.

# %%
# Group: Ayad, Keane, Cameron, Aaron
# Section: 502
from sympy import *
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
t = symbols('t')

xt = exp(2*sin(t))
yt = exp(cos(t))

dx = diff(xt, t)
dy = diff(yt, t)

mx = dx.subs(t, pi/6)
my = dy.subs(t, pi/6)
slope = my/mx


x0 = xt.subs(t, pi/6)
y0 = yt.subs(t, pi/6)


# print correct format for tangent line
print(f"This is the tangent line for this function at pi/6:\ny-{y0}={slope}(x-{x0})")
# Out:
# This is the tangent line for this function at pi/6:
# y-exp(sqrt(3)/2)=-sqrt(3)*exp(-1)*exp(sqrt(3)/2)/6(x-E)

# %% [markdown]
# #### 1b

# %%
# horizontal when dy = 0
horizontal = solve(dy, t)
xh1 = xt.subs(t, horizontal[0])
yh1 = yt.subs(t, horizontal[0])
xh2 = xt.subs(t, horizontal[1])
yh2 = yt.subs(t, horizontal[1])
print(f"These are the points where there is a horizontal tangent:\n({xh1}, {yh1}) and ({xh2}, {yh2})")

#vertical when dx = 0
vert = solve(dx, t)
xv1 = xt.subs(t, vert[0])
yv1 = yt.subs(t, vert[0])
xv2 = xt.subs(t, vert[1])
yv2 = yt.subs(t, vert[1])
print(f"These are the points where there is a vertical tangent:\n({xv1}, {yv1}) and ({xv2}, {yv2})")

# make sure to print correct statement
# Out:
# These are the points where there is a horizontal tangent:
# (1, E) and (1, exp(-1))
# These are the points where there is a vertical tangent:
# (exp(2), 1) and (exp(-2), 1)

# %% [markdown]
# #### 1c

# %%
matplotlib notebook

# %%
plot_parametric((xt, yt, (t,0,2*pi)), (t, exp(1), (t,0,2*pi)), (exp(2), t, (t,0,pi)), (t, exp(-1), (t,0,2*pi)), (exp(-2), t, (t,0, pi)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
x, y = symbols('x y')
f = x**2 + 2*x + 3*y**2-8
dydx = idiff(f, y, x)
print(f"This is the derivative of the function:\n{dydx}")
# Out:
# This is the derivative of the function:
# -(x + 1)/(3*y)

# %% [markdown]
# #### 2b

# %%
num, den = fraction(dydx)

horiz = solve([num, f], [x, y])
print(f"These are the points where there is a horizontal tangent: {horiz}")
# Out:
# These are the points where there is a horizontal tangent: [(-1, -sqrt(3)), (-1, sqrt(3))]

# %% [markdown]
# #### 2c

# %%
vert = solve([den, f], [x, y])
print(f"These are the points where there is a vertical tangent: {vert}")
# Out:
# These are the points where there is a vertical tangent: [(-4, 0), (2, 0)]

# %% [markdown]
# #### 2d

# %%
matplotlib notebook

# %%
p1 = plot_implicit(f, show=False)
p2 = plot_parametric((t, -sqrt(3), (t,-4,2)), (-4, t, (t,-2,2)), (t, sqrt(3), (t,-4,2)), (2, t, (t,-2,2)), show=False)
p1.extend(p2)
p1.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
y0, t, k = symbols('y0 t k', real=True)
y = y0 * exp(k*t)
sol = solve([y.subs(t, 2)-1000, y.subs(t, 6)-40000], [y0, k])
yy = y.subs(y0, sol[0][0])
yk = yy.subs(k, sol[0][1])
print(f"y0 = {yy}")
print(f"k = {yk}")
# Out:
# y0 = 50*sqrt(10)*exp(k*t)
# k = 50*sqrt(10)*exp(t*log(40)/4)

# %% [markdown]
# #### 3b

# %%
tsol = solve(yk-2000000, t)
print(f"The bacteria count reaches 2,000,000 at time: {tsol}")
# Out:
# The bacteria count reaches 2,000,000 at time: [4*(log(10)/2 + log(4000))/log(40)]

# %% [markdown]
# #### 3c

# %%
y0, t, k = symbols('y0 t k', real = True)

y = y0*exp(k*t)

sol = solve([y.subs(t,0)-1000, y.subs(t,4)-40000], [y0,k])


yy = y.subs(y0, sol[0][0])
yk = yy.subs(k, sol[0][1])

print(yy)
print('k = ', yk)

print('The graph will be the same, just with a different domain')
# Out:
# 1000*exp(k*t)
# k =  1000*exp(t*log(40)/4)
# The graph will be the same, just with a different domain
