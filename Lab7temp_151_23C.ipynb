# %% [markdown]
# ## MATH 151 Lab 7

# %% [markdown]
# Put team members' names and section number here.

# %%
# Ayad, Keane, Aaron, Cameron
from sympy import *
from sympy.plotting import (plot,plot_parametric)

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### 1a

# %%
x = symbols('x')
f = (x**2 + 8*x + 5)/(x**2)

df = diff(f, x)

criticalVal = solve(df, x)

criticalVal.append(-1)
criticalVal.append(-3)
print(f"These are the critical values: {criticalVal}")

fVals = [f.subs(x, i) for i in criticalVal]
print(f"This is the absolute max: {max(fVals)}")
print(f"This is the absolute min: {min(fVals)}")
# Out:
# These are the critical values: [-5/4, -1, -3]
# This is the absolute max: -10/9
# This is the absolute min: -11/5

# %% [markdown]
# #### 1b

# %%
x = symbols('x')
f = (x**2 + 8*x + 5)/(x**2)

df = diff(f, x)

criticalVal = solve(df, x)

criticalVal.append(1)
criticalVal.append(-3)
print(f"These are the critical values: {criticalVal}")

fVals = [f.subs(x, i) for i in criticalVal]
print(f"This is the absolute max: {max(fVals)}")
print(f"This is the absolute min: {min(fVals)}")
print("These values cannot be trusted because the extreme value theorem does not hold because the function is not continious over this interval.")
# Out:
# These are the critical values: [-5/4, 1, -3]
# This is the absolute max: 14
# This is the absolute min: -11/5
# These values cannot be trusted because the extreme value theorem does not hold because the function is not continious over this interval

# %% [markdown]
# #### 1c

# %%
matplotlib notebook

# %%
plot(f, (x,-3,1), ylim=[-3, 20])
print(f"There is no absolute max, but there is an absolute min at -11/5")
# Out:
# <img src="data:image/png;base64,..." width="640">
# There is no absolute max, but there is an absolute min at -11/5

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### 2a

# %%
x = symbols('x')
f = 4*x**3 - 3*x**2 + 2*x - 1
slope = (f.subs(x, 7) - f.subs(x, 2))/5
df = diff(f, x)
cVal = solve(df - slope, x)
print(f"This is the c value: {cVal[1]}")
# Out:
# This is the c value: 1/4 + sqrt(2901)/12

# %% [markdown]
# #### 2b

# %%
matplotlib notebook

# %%
p1 = plot(f, (x,2,7), show=False)
yp = f.subs(x, cVal[1])
tanL = yp + slope*(x-cVal[1])
p2 = plot(tanL, (x,2,7), show = False)
secL = slope*x - 465
p3 = plot(secL, (x,2,7), show=False)
p1.extend(p2)
p1.extend(p3)
p1.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### 3a

# %%
x = symbols('x')
f1 = 8 - x**2
f2 = 5*exp((x-2)/2) - x
df1 = diff(f1, x)
cVal1 = solve(df1, x)
df2 = diff(f2, x)
cVal2 = solve(df2, x)
print(f"These are the critical values: {cVal1[0]}, {cVal2[0]}")
# Out:
# These are the critical values: 0, log(4*exp(2)/25)

# %% [markdown]
# #### 3b

# %%
critical_val1 = solve(df1, x)
critical_val1.append(-5)
critical_val1.append(5)
fVals1 = [f.subs(x, i) for i in critical_val1]


critical_val2 = solve(df2, x)
critical_val2.append(-5)
critical_val2.append(5)
fVals2 = [f.subs(x, i) for i in critical_val2]
values = fVals1 + fVals2
print(f"There is no absolute max in this range, but there is a absolute min at {min(values)}.")
# Out:
# There is no absolute max in this range, but there is a absolute min at -586

# %% [markdown]
# #### 3c

# %%
matplotlib notebook

# %%
p1 = plot(f1, (x,-5, 0), show=False)
p2 = plot(f2, (x, 0, 5), show=False)
p1.extend(p2)
p1.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
